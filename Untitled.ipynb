# %%
from src.language import Language

# %%
ph = {
    "C": ["p", "t", "k", "b", "d", "h", "n", "m", "r", "l"],
    "V": ["a", "e", "o", "u"]
}
pt = ["CV", "VCV", "CVCV", "VCVCV", "V", "CVCVCV"]
st = [0,1,2]

l = Language(ph, pt, st)

# %%
l.generate_vocabulary()

# %%
l.vocabulary
# Out:
# I: 'ku
# and: 'pu
# in: 'o
# not: e'tu
# you (singular): 'u
# you (plural): 'aba
# with: 'tu
# they (singular): 'ope
# they (plural): a'do
# at: 'ate
# this: 'a
# we: 'eno
# that: 'no
# to say: 'pa
# what: 'ke
# all: 'po
# if: 'eho
# who: 'eta
# one: 'aku
# to see: 'ho
# to know: 'opa
# some: 'de
# year: 'e
# two: 'eto
# to think: 'apu
# to come: 'otu
# other: 'epa
# to give: 'ode
# good: 'bo
# new: e'pe
# how: 'are
# man (adult male): 'ake
# man (human being): 'eka
# day: 'upe
# many: 'da
# because: 'do
# three: 'ma
# there: 'be
# child: 'na
# here: 'te
# old: 'pe
# woman: 'mu
# where: 'to
# hand: 'epo
# small: u'ta
# to hold: 'upa
# four: 'apa
# to turn (intransitive): o'do
# few: 'ete
# when: 'utu
# five: bo'pa
# head: 'ro
# night: 'hapu
# long: 'abo
# eye: 'betedu
# to play: 'ato
# water: 'pabana
# to hear: mata'pa
# right: 'etemu
# big: ata'be
# to live: e'ba
# to stand: 'odo
# name: 'uke
# road: eta'to
# to sit: u'me
# mother: 'doboto
# full: 'du
# far: bada'ra
# ...
